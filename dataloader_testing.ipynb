# %%
import torch

# %%
from modules.dataloaders import *

# %%
train_loader, val_loader, test_loader = get_sers_dataloaders()
# Out:
# Dataset type train -> Loaded 99 images
# Dataset type val -> Loaded 35 images
# Dataset type test -> Loaded 36 images

# %%
fig, ax = plt.subplots(figsize=(10,5))


for idx, (x, y) in enumerate(test_loader):
    series = np.arange(0,x.shape[1])
    
    ax.plot(series, x[0], label=f'{y[0]}')
    
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(10,5))


for idx, (x, y) in enumerate(val_loader):
    series = np.arange(0,x.shape[1])
    
    ax.plot(series, x[0], label=f'{y[0]}')
    
ax.legend()
